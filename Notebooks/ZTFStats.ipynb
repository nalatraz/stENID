# %% [markdown]
# # Initialize

# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Load data

# %%
TNS = pd.read_csv("tns_public_objects.csv",skiprows=1)

# %%
TNS.head()
# Out:
#    objid name_prefix      name          ra  declination  redshift  typeid  \
# 0  95186          AT  2021acxj   56.209897    -6.178407       NaN     NaN
# 1  95185          AT  2021acxi  355.404620    -6.473544       NaN     NaN
# 2  95184          AT  2021acxh  312.469017     3.341450       NaN     NaN
# 3  95183          AT  2021acxg   68.456500   -60.820611       NaN     NaN
# 4  95182          AT  2021acxf   24.122136    -7.602172       NaN     NaN
#
#   type  reporting_groupid reporting_group         ...           source_group  \
# 0  NaN               18.0           ATLAS         ...                  ATLAS
# 1  NaN               18.0           ATLAS         ...                  ATLAS
# 2  NaN               18.0           ATLAS         ...                  ATLAS
# 3  NaN               36.0          MASTER         ...                 MASTER
# 4  NaN                4.0     Pan-STARRS1         ...            Pan-STARRS1
#
# ...

# %% [markdown]
# # Convert to smaller table

# %%
TNSshort = TNS[['objid','name_prefix','name','internal_names','type','typeid']] # To make it easier to work with. Not used in the function.

# %% [markdown]
# # Extract ZTF

# %%
TNSshort['internal_names'] = TNSshort['internal_names'] + ',' # To make it searchable
# Out:
# /Users/davidivens/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
ZTFsub = 'ZTF' + TNSshort['internal_names'].str.extract('ZTF(.+?),')

# %%
ZTFextracts = pd.notna(ZTFsub)

# %%
TNSZTF = TNSshort[ZTFextracts.values]

# %%
TNSZTF['internal_names'] = ZTFsub
# Out:
# /Users/davidivens/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Count types

# %%
TNSZTF
# Out:
#        objid name_prefix      name internal_names     type  typeid
# 11     95175          AT  2021acwy   ZTF21acizlsw      NaN     NaN
# 12     95174          AT  2021acwx   ZTF21acjvqnq      NaN     NaN
# 13     95173          AT  2021acww   ZTF21acjjtmh      NaN     NaN
# 26     95160          AT  2021acwj   ZTF21acjxpdv      NaN     NaN
# 27     95159          AT  2021acwi   ZTF21acjxiyh      NaN     NaN
# 28     95158          AT  2021acwh   ZTF21acjxjpu      NaN     NaN
# 29     95157          AT  2021acwg   ZTF21acjvcre      NaN     NaN
# 30     95156          AT  2021acwf   ZTF21acjowmq      NaN     NaN
# 31     95155          AT  2021acwe   ZTF21abtzbub      NaN     NaN
# 32     95154          AT  2021acwd   ZTF21acizsqx      NaN     NaN
# 33     95153          AT  2021acwc   ZTF21acjvjhq      NaN     NaN
# 34     95152          AT  2021acwb   ZTF21acjpwbh      NaN     NaN
# 35     95151          AT  2021acwa   ZTF21acjouph      NaN     NaN
# ...

# %% [markdown]
# # As a function

# %%
def ZTFandtype(csvfile):
    TNS = pd.read_csv(csvfile,skiprows=1)
    TNS['internal_names'] = TNS['internal_names'] + ','
    ZTFsub = 'ZTF' + TNS['internal_names'].str.extract('ZTF(.+?),')
    ZTFextracts = pd.notna(ZTFsub)
    TNSZTF = TNS[ZTFextracts.values]
    TNSZTF['internal_names'] = ZTFsub
    return TNSZTF
